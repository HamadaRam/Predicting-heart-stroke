# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split  
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("healthcare-dataset-stroke-data.csv")

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
df.head
# Out:
# <bound method NDFrame.head of          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]>

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# Checking for duplicate value

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5105    False
# 5106    False
# 5107    False
# 5108    False
# 5109    False
# Length: 5110, dtype: bool

# %% [markdown]
# Checking for null values

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# We can see that there are 201 null values in bmi column. Instead of removing the null values, we will fill the null values with the mean bmi

# %%
df['bmi'].fillna(df['bmi'].mean(),inplace = True)

# %%
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.age
# Out:
# 0       67.0
# 1       61.0
# 2       80.0
# 3       49.0
# 4       79.0
#         ...
# 5105    80.0
# 5106    81.0
# 5107    35.0
# 5108    51.0
# 5109    44.0
# Name: age, Length: 5110, dtype: float64

# %% [markdown]
# We can see that age is in float, so we change it to int

# %%
print(df[df['age'].isnull()])
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
df['age']= df['age'].astype(int)

# %%
df.age
# Out:
# 0       67
# 1       61
# 2       80
# 3       49
# 4       79
#         ..
# 5105    80
# 5106    81
# 5107    35
# 5108    51
# 5109    44
# Name: age, Length: 5110, dtype: int64

# %% [markdown]
# Creating a variable called Bmi to store the specific bmi of the users

# %%
Bmi = pd.cut(df['bmi'], bins=[0, 19, 25, 100], labels=['Underweight', 'Ideal', 'Overweight or obese'])

# %%
Bmi.unique()
# Out:
# ['Overweight or obese', 'Ideal', 'Underweight']
# Categories (3, object): ['Underweight' < 'Ideal' < 'Overweight or obese']

# %% [markdown]
# Creating a variable called Agegroup to store specific age of the users

# %%
Agegroup = pd.cut(df['age'], bins=[0, 18, 50, 100], labels=['Below 18', '18 - 50', 'Above 50'])

# %%
Agegroup.unique()
# Out:
# ['Above 50', '18 - 50', 'Below 18', NaN]
# Categories (3, object): ['Below 18' < '18 - 50' < 'Above 50']

# %% [markdown]
# # EDA

# %% [markdown]
# Let's see the no of people that suffered stroke

# %%
data1 = list(df['stroke'].value_counts())
circle = [data1[0] / sum(data1) * 100,data1[1] / sum(data1) * 100]
colors = ['Green','Red']

plt.subplots(figsize = (8,8))
ax = sns.countplot('stroke',data = df, palette = colors,edgecolor = 'black')
for rect in ax.patches:
    ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height() + 2, rect.get_height(), horizontalalignment='center', fontsize = 15)
ax.set_xticklabels(['No Stroke Suffered','Stroke Suffered'])
plt.title('Total Strokes');
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# The genders recorded in our dataset

# %%
data = list(df['gender'].value_counts())
circle = [data[0] / sum(data) * 100,data[1] / sum(data) * 100]
colors = ['Blue','Pink','red']

plt.subplots(figsize = (8,8))
ax = sns.countplot('gender',data = df, palette = colors,edgecolor = 'black')
for rect in ax.patches:
    ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height() + 2, rect.get_height(), horizontalalignment='center', fontsize = 15)
ax.set_xticklabels(['Male','Female','others'])
plt.title('Genders');
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Percentage of patients with hypertension or not

# %%
l = list(df['hypertension'].value_counts())
colors=['Orange','yellow']
circle = [l[0] / sum(l) * 100,l[1] / sum(l) * 100]
plt.pie(circle,labels = ['No','Yes'],autopct='%1.1f%%',startangle = 90,explode = (0.1,0),colors = colors,
       wedgeprops = {'edgecolor' : 'black','linewidth': 1,'antialiased' : True})
plt.title('Hypertension');

# %% [markdown]
# Plotting all the other improtant data in the form of graph. We will mainly focus on these data for this project

# %%
fig,axes = plt.subplots(2,2,figsize = (15,15))
sns.set_style('dark')
fig.suptitle("Our Target Categories")
colors = ['Green','Red']
colors2= ['Yellow','blue']
colors3= ['orange','Green','red','yellow']
sns.countplot(ax=axes[0,0],data=df,x='heart_disease',palette = colors)
sns.countplot(ax=axes[0,1],data=df,x='Residence_type',palette = colors2)
sns.countplot(ax=axes[1,0],data=df,x='smoking_status',palette = colors3)
sns.countplot(ax=axes[1,1],data=df,x='stroke',palette = colors)

plt.show()

# %% [markdown]
# Age group Based on Gender

# %%
plt.figure(figsize=(22,11))
sns.histplot(
    df, x="age", hue="gender",
    element="step",
     common_norm=False,
)
plt.title('Count of age group based on gender', fontsize=15)
plt.show()

# %% [markdown]
# Distribution of Age with BMI

# %%
fig = px.box(df,y="age",x="bmi",title=f"Distrubution of Age with bmi")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="df56f4b3-becc-4acd-b955-f2a7c94c1aad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df56f4b3-becc-4acd-b955-f2a7c94c1aad")) {                    Plotly.newPlot(                        "df56f4b3-becc-4acd-b955-f2a7c94c1aad",                        [{"alignmentgroup":"True","hovertemplate":"bmi=%{x}<br>age=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[36.6,28.893236911794666,32.5,34.4,24.0,29.0,27.4,22.8,28.893236911794666,24.2,29.7,36.8,27.3,28.893236911794666,28.2,30.9,37.5,25.8,37.8,28.893236911794666,22.4,48.9,26.6,32.5,27.2,23.5,28.2,28.893236911794666,28.3,28.893236911794666,44.2,25.4,22.2,30.5,29.7,26.5,33.7,23.1,32.0,29.9,23.9,28.5,26.4,28.893236911794666,20.2,33.6,28.893236911794666,38.6,33.7,39.2,28.893236911794666,28.893236911794666,27.7,31.4,28.893236911794666,36.5,33.2,28.893236911794666,32.8,27.7,40.4,22.2,25.3,30.2,28.893236911794666,24.0,47.5,20.3,30.0,28.9,28.893236911794666,28.1,31.1,27.4,26.4,21.7,27.0,24.1,28.893236911794666,45.9,44.1,28.893236911794666,22.9,29.7,28.893236911794666,29.1,27.3,32.3,41.1,25.6,29.8,26.3,37.5,26.2,29.4,32.3,24.4,31.4,27.7,28.0,28.8,31.4,34.6,19.4,28.5,28.893236911794666,30.3,40.4,24.2,41.5,22.6,24.2,28.893236911794666,56.6,27.1,30.9,27.3,31.3,24.0,31.0,28.0,30.3,31.7,35.8,28.893236911794666,28.4,28.893236911794666,24.0,29.0,28.893236911794666,36.5,20.1,36.5,28.893236911794666,26.7,38.7,29.9,34.9,27.0,26.6,25.0,23.8,21.8,36.8,30.0,27.5,28.893236911794666,24.6,32.9,26.1,28.893236911794666,31.9,34.1,27.5,25.6,36.9,31.4,37.3,34.1,25.0,28.893236911794666,28.893236911794666,28.893236911794666,45.7,34.2,23.6,27.3,28.893236911794666,22.3,31.4,28.893236911794666,28.893236911794666,26.4,32.9,28.893236911794666,37.1,45.0,25.5,28.893236911794666,26.1,30.8,32.0,29.9,28.893236911794666,37.4,31.7,34.5,27.9,29.5,28.893236911794666,46.0,42.5,35.5,31.1,26.9,35.8,45.5,28.5,28.893236911794666,26.6,28.893236911794666,31.5,32.0,30.8,31.1,33.0,23.4,26.9,33.6,23.9,26.3,27.3,30.7,20.5,21.5,31.0,27.1,40.0,28.893236911794666,28.6,28.1,28.4,42.2,25.8,31.9,31.0,27.5,28.893236911794666,29.6,35.4,16.9,21.5,34.4,28.0,26.8,39.3,31.7,32.6,28.4,35.9,21.2,34.5,42.4,40.5,36.7,30.9,29.3,28.893236911794666,19.6,18.0,39.2,17.6,35.9,19.1,50.1,17.7,27.0,32.3,54.6,35.0,22.0,39.4,26.1,42.4,33.0,19.7,22.5,24.6,25.2,41.8,60.9,31.5,27.3,23.7,24.5,28.4,26.9,26.7,31.2,25.0,25.4,27.5,16.0,27.0,31.6,25.1,30.9,24.8,23.4,29.4,18.3,20.0,19.5,36.0,27.7,27.5,28.5,26.8,33.6,29.1,28.5,34.9,25.1,35.3,26.4,31.5,40.1,43.1,36.7,29.3,21.2,31.2,21.4,27.9,34.3,31.0,27.7,36.0,38.7,27.6,25.1,16.5,22.8,35.4,24.3,34.3,40.1,25.7,21.9,38.4,26.1,30.5,25.9,54.7,29.9,18.6,27.1,24.9,25.2,19.4,29.0,48.2,28.893236911794666,34.6,24.6,25.8,26.1,29.0,27.2,20.7,30.0,37.3,34.1,23.6,25.2,39.5,23.5,23.3,64.8,28.1,28.893236911794666,24.4,29.8,24.9,35.1,32.3,43.6,21.0,47.3,16.6,37.5,24.2,31.6,21.6,31.0,31.1,15.5,27.3,20.5,35.6,16.7,41.8,41.9,16.4,17.1,29.2,27.1,37.9,44.6,22.8,33.2,22.3,26.4,39.6,28.1,39.2,36.0,37.8,40.3,41.5,17.7,21.2,41.6,23.8,23.7,24.8,39.0,37.9,31.1,23.2,18.9,36.1,36.3,40.5,25.4,46.5,16.8,46.6,26.4,26.2,35.2,20.9,36.8,34.4,22.2,13.8,40.3,28.4,31.7,34.2,54.7,24.6,28.893236911794666,36.9,31.1,31.9,31.8,18.0,28.5,29.5,22.0,29.4,28.8,26.2,26.9,23.2,27.9,36.8,28.9,31.0,29.4,15.3,37.1,30.5,38.2,23.2,30.2,45.2,21.8,24.4,17.0,19.5,49.8,27.8,25.1,26.8,60.2,27.5,28.1,27.3,27.4,22.2,22.9,26.6,23.0,32.6,22.1,28.893236911794666,22.5,28.893236911794666,25.5,31.4,26.0,20.0,31.6,31.2,21.7,24.2,25.0,36.7,28.9,29.7,44.3,51.0,39.7,34.7,35.0,21.3,29.1,23.9,36.0,41.2,27.1,33.2,25.4,30.7,34.8,19.2,31.7,35.7,37.8,29.7,35.8,23.6,39.7,40.5,21.4,40.8,24.7,21.0,45.0,26.2,28. ...

# %% [markdown]
# Scatterplot of Age, BMI and smoking_status

# %%
plt.figure(figsize=(30,15))
sns.scatterplot(x='age', y='bmi', hue='smoking_status', data=df)
plt.xlabel("Age")
plt.ylabel("Bmi");

# %% [markdown]
# # Visualization

# %% [markdown]
# **Visualizing our hypothesis**

# %% [markdown]
# Showing the Specific Age group of people who suffered stroke

# %%
data1 = list(df['stroke'].value_counts())
circle = [data1[0] / sum(data1) * 100,data1[1] / sum(data1) * 100]
colors = ['Lime','bisque','teal']

plt.subplots(figsize = (8,8))
ax = sns.countplot('stroke',data = df, palette = colors,edgecolor = 'black',hue=Agegroup)
for rect in ax.patches:
    ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height() + 2, rect.get_height(), horizontalalignment='center', fontsize = 15)
ax.set_xticklabels(['No Stroke','Stroke'])
plt.title('Total Strokes');
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Showing the specific BMI of our users

# %%
color=['Green','Red']
sns.countplot(Bmi,palette=color,hue=df['stroke'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
data1 = list(df['stroke'].value_counts())
circle = [data1[0] / sum(data1) * 100,data1[1] / sum(data1) * 100]
colors = ['Orange','Green','Red']

plt.subplots(figsize = (8,8))
ax = sns.countplot('stroke',data = df, palette = colors,edgecolor = 'black',hue=Bmi)
for rect in ax.patches:
    ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height() + 2, rect.get_height(), horizontalalignment='center', fontsize = 15)
ax.set_xticklabels(['No Stroke','Stroke'])
plt.title('Total Strokes');
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Shwoing the urban and rural population and number of stroke occured in each

# %%
data1 = list(df['stroke'].value_counts())
circle = [data1[0] / sum(data1) * 100,data1[1] / sum(data1) * 100]
colors = ['Violet','yellow']

plt.subplots(figsize = (8,8))
ax = sns.countplot('stroke',data = df, palette = colors,edgecolor = 'black',hue=df['Residence_type'])
for rect in ax.patches:
    ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height() + 2, rect.get_height(), horizontalalignment='center', fontsize = 15)
ax.set_xticklabels(['No Stroke','Stroke'])
plt.title('Total Strokes');
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Shwoing smokers and non smokers with stroke

# %%
data1 = list(df['stroke'].value_counts())
circle = [data1[0] / sum(data1) * 100,data1[1] / sum(data1) * 100]
colors = ['Yellow','Green','Red','Lightblue']

plt.subplots(figsize = (8,8))
ax = sns.countplot('stroke',data = df, palette = colors,edgecolor = 'black',hue=df['smoking_status'])
for rect in ax.patches:
    ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height() + 2, rect.get_height(), horizontalalignment='center', fontsize = 15)
ax.set_xticklabels(['No Stroke','Stroke'])
plt.title('Total Strokes');
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# # *Feature Selection*

# %% [markdown]
# Tree-based feature selection

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel


clf = ExtraTreesClassifier(n_estimators=50)
clf.fit(X, y)
clf.feature_importances_
model = SelectFromModel(clf, prefit=True)
X_new = model.transform(X)
X_new.shape  # notice here the number of features in the data has been decreased

# %% [markdown]
# # Model Development and Testing

# %% [markdown]
# Here, we show the correlation matrix. However, we don't need the id column so we drop that column first.
# Note: This correlation matrix is only for data with numerical values

# %%
newdf = df.drop("id", axis='columns')

# %%
correlation = newdf.corr()
correlation.style.background_gradient(cmap='coolwarm',axis=None)
# Out:
# <style type="text/css">
# #T_89514_row0_col0, #T_89514_row1_col1, #T_89514_row2_col2, #T_89514_row3_col3, #T_89514_row4_col4, #T_89514_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_89514_row0_col1, #T_89514_row1_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_89514_row0_col2, #T_89514_row2_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_89514_row0_col3, #T_89514_row3_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_89514_row0_col4, #T_89514_row4_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_89514_row0_col5, #T_89514_row5_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_89514_row1_col2, #T_89514_row2_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_89514_row1_col3, #T_89514_row3_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_89514_row1_col4, #T_89514_row2_col3, #T_89514_row3_col2, #T_89514_row4_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_89514_row1_col5, #T_89514_row5_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_89514_row2_col4, #T_89514_row4_col2, #T_89514_row4_col5, #T_89514_row5_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_89514_row2_col5, #T_89514_row5_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_89514_row3_col4, #T_89514_row4_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_89514_row3_col5, #T_89514_row5_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_89514_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >hypertension</th>
#       <th class="col_heading level0 col2" >heart_disease</th>
#       <th class="col_heading level0 col3" >avg_glucose_level</th>
#       <th class="col_heading level0 col4" >bmi</th>
#       <th class="col_heading level0 col5" >stroke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89514_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_89514_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_89514_row0_col1" class="data row0 col1" >0.276303</td>
#       <td id="T_89514_row0_col2" class="data row0 col2" >0.263668</td>
#       <td id="T_89514_row0_col3" class="data row0 col3" >0.238060</td>
#       <td id="T_89514_row0_col4" class="data row0 col4" >0.326271</td>
#       <td id="T_89514_row0_col5" class="data row0 col5" >0.245128</td>
#     </tr>
#     <tr>
#       <th id="T_89514_level0_row1" class="row_heading level0 row1" >hypertension</th>
#       <td id="T_89514_row1_col0" class="data row1 col0" >0.276303</td>
#       <td id="T_89514_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_89514_row1_col2" class="data row1 col2" >0.108306</td>
#       <td id="T_89514_row1_col3" class="data row1 col3" >0.174474</td>
#       <td id="T_89514_row1_col4" class="data row1 col4" >0.160189</td>
#       <td id="T_89514_row1_col5" class="data row1 col5" >0.127904</td>
#     </tr>
#     <tr>
#       <th id="T_89514_level0_row2" class="row_heading level0 row2" >heart_disease</th>
#       <td id="T_89514_row2_col0" class="data row2 col0" >0.263668</td>
#       <td id="T_89514_row2_col1" class="data row2 col1" >0.108306</td>
#       <td id="T_89514_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_89514_row2_col3" class="data row2 col3" >0.161857</td>
#       <td id="T_89514_row2_col4" class="data row2 col4" >0.038899</td>
#       <td id="T_89514_row2_col5" class="data row2 col5" >0.134914</td>
#     </tr>
#     <tr>
#       <th id="T_89514_level0_row3" class="row_heading level0 row3" >avg_glucose_level</th>
#       <td id="T_89514_row3_col0" class="data row3 col0" >0.238060</td>
#       <td id="T_89514_row3_col1" class="data row3 col1" >0.174474</td>
#       <td id="T_89514_row3_col2" class="data row3 col2" >0.161857</td>
#       <td id="T_89514_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_89514_row3_col4" class="data row3 col4" >0.168751</td>
#       <td id="T_89514_row3_col5" class="data row3 col5" >0.131945</td>
#     </tr>
#     <tr>
#       <th id="T_89514_level0_row4" class="row_heading level0 row4" >bmi</th>
#       <td id="T_89514_row4_col0" class="data row4 col0" >0.326271</td>
#       <td id="T_89514_row4_col1" class="data row4 col1" >0.160189</td>
#       <td id="T_89514_row4_col2" class="data row4 col2" >0.038899</td>
#       <td id="T_89514_row4_col3" class="data row4 col3" >0.168751</td>
#       <td id="T_89514_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_89514_row4_col5" class="data row4 col5" >0.038947</td>
#     </tr>
#     <tr>
#       <th id="T_89514_level0_row5" class="row_heading level0 row5" >stroke</th>
#       <td id="T_89514_row5_col0" class="data row5 col0" >0.245128</td>
#       <td id="T_89514_row5_col1" class="data row5 col1" >0.127904</td>
#       <td id="T_89514_row5_col2" class="data row5 col2" >0.134914</td>
#       <td id="T_89514_row5_col3" class="data row5 col3" >0.131945</td>
#       <td id="T_89514_row5_col4" class="data row5 col4" >0.038947</td>
#       <td id="T_89514_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# First step is to make the data numerical

# %%
l=LabelEncoder()
newdf=newdf.apply(l.fit_transform).astype(int)

# %% [markdown]
# This is the correlation matrix of all the data once converted into numerical values

# %%
correlation = newdf.corr()
correlation.style.background_gradient(cmap='coolwarm',axis=None)
# Out:
# <style type="text/css">
# #T_d4402_row0_col0, #T_d4402_row1_col1, #T_d4402_row2_col2, #T_d4402_row3_col3, #T_d4402_row4_col4, #T_d4402_row5_col5, #T_d4402_row6_col6, #T_d4402_row7_col7, #T_d4402_row8_col8, #T_d4402_row9_col9, #T_d4402_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d4402_row0_col1, #T_d4402_row0_col4, #T_d4402_row1_col0, #T_d4402_row3_col5, #T_d4402_row4_col0, #T_d4402_row5_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_d4402_row0_col2, #T_d4402_row2_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_d4402_row0_col3, #T_d4402_row3_col0, #T_d4402_row7_col10, #T_d4402_row10_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_d4402_row0_col5, #T_d4402_row5_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_d4402_row0_col6, #T_d4402_row2_col6, #T_d4402_row5_col6, #T_d4402_row6_col0, #T_d4402_row6_col2, #T_d4402_row6_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_d4402_row0_col7, #T_d4402_row3_col9, #T_d4402_row7_col0, #T_d4402_row9_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_d4402_row0_col8, #T_d4402_row5_col7, #T_d4402_row7_col5, #T_d4402_row8_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_d4402_row0_col9, #T_d4402_row9_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_d4402_row0_col10, #T_d4402_row4_col6, #T_d4402_row6_col4, #T_d4402_row6_col9, #T_d4402_row9_col6, #T_d4402_row10_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_d4402_row1_col2, #T_d4402_row2_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_d4402_row1_col3, #T_d4402_row1_col9, #T_d4402_row3_col1, #T_d4402_row9_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_d4402_row1_col4, #T_d4402_row4_col1 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_d4402_row1_col5, #T_d4402_row5_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d4402_row1_col6, #T_d4402_row6_col1, #T_d4402_row6_col10, #T_d4402_row10_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_d4402_row1_col7, #T_d4402_row7_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_d4402_row1_col8, #T_d4402_row8_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_d4402_row1_col10, #T_d4402_row10_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_d4402_row2_col3, #T_d4402_row2_col9, #T_d4402_row3_col2, #T_d4402_row4_col10, #T_d4402_row9_col2, #T_d4402_row10_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_d4402_row2_col4, #T_d4402_row4_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_d4402_row2_col5, #T_d4402_row5_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_d4402_row2_col7, #T_d4402_row7_col2, #T_d4402_row7_col8, #T_d4402_row8_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_d4402_row2_col8, #T_d4402_row8_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_d4402_row2_col10, #T_d4402_row10_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_d4402_row3_col4, #T_d4402_row3_col7, #T_d4402_row4_col3, #T_d4402_row7_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_d4402_row3_col6, #T_d4402_row6_col3, #T_d4402_row6_col8, #T_d4402_row8_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_d4402_row3_col8, #T_d4402_row8_col3, #T_d4402_row8_col10, #T_d4402_row10_col8 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_d4402_row3_col10, #T_d4402_row10_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_d4402_row4_col5, #T_d4402_row5_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d4402_row4_col7, #T_d4402_row7_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_d4402_row4_col8, #T_d4402_row8_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_d4402_row4_col9, #T_d4402_row9_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_d4402_row5_col8, #T_d4402_row8_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d4402_row5_col9, #T_d4402_row9_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_d4402_row5_col10, #T_d4402_row10_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_d4402_row6_col7, #T_d4402_row7_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_d4402_row7_col9, #T_d4402_row9_col7 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_d4402_row8_col9, #T_d4402_row9_col8 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_d4402_row9_col10, #T_d4402_row10_col9 {
#   background-color: #9abbff;
#   color: #000000;
# }
# </style>
# <table id="T_d4402_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >gender</th>
#       <th class="col_heading level0 col1" >age</th>
#       <th class="col_heading level0 col2" >hypertension</th>
#       <th class="col_heading level0 col3" >heart_disease</th>
#       <th class="col_heading level0 col4" >ever_married</th>
#       <th class="col_heading level0 col5" >work_type</th>
#       <th class="col_heading level0 col6" >Residence_type</th>
#       <th class="col_heading level0 col7" >avg_glucose_level</th>
#       <th class="col_heading level0 col8" >bmi</th>
#       <th class="col_heading level0 col9" >smoking_status</th>
#       <th class="col_heading level0 col10" >stroke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4402_level0_row0" class="row_heading level0 row0" >gender</th>
#       <td id="T_d4402_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d4402_row0_col1" class="data row0 col1" >-0.028304</td>
#       <td id="T_d4402_row0_col2" class="data row0 col2" >0.020994</td>
#       <td id="T_d4402_row0_col3" class="data row0 col3" >0.085447</td>
#       <td id="T_d4402_row0_col4" class="data row0 col4" >-0.031005</td>
#       <td id="T_d4402_row0_col5" class="data row0 col5" >0.056422</td>
#       <td id="T_d4402_row0_col6" class="data row0 col6" >-0.006738</td>
#       <td id="T_d4402_row0_col7" class="data row0 col7" >0.050396</td>
#       <td id="T_d4402_row0_col8" class="data row0 col8" >-0.026778</td>
#       <td id="T_d4402_row0_col9" class="data row0 col9" >-0.062581</td>
#       <td id="T_d4402_row0_col10" class="data row0 col10" >0.008929</td>
#     </tr>
#     <tr>
#       <th id="T_d4402_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_d4402_row1_col0" class="data row1 col0" >-0.028304</td>
#       <td id="T_d4402_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d4402_row1_col2" class="data row1 col2" >0.276303</td>
#       <td id="T_d4402_row1_col3" class="data row1 col3" >0.263668</td>
#       <td id="T_d4402_row1_col4" class="data row1 col4" >0.679181</td>
#       <td id="T_d4402_row1_col5" class="data row1 col5" >-0.362146</td>
#       <td id="T_d4402_row1_col6" class="data row1 col6" >0.014169</td>
#       <td id="T_d4402_row1_col7" class="data row1 col7" >0.152391</td>
#       <td id="T_d4402_row1_col8" class="data row1 col8" >0.342042</td>
#       <td id="T_d4402_row1_col9" class="data row1 col9" >0.265595</td>
#       <td id="T_d4402_row1_col10" class="data row1 col10" >0.245128</td>
#     </tr>
#     <tr>
#       <th id="T_d4402_level0_row2" class="row_heading level0 row2" >hypertension</th>
#       <td id="T_d4402_row2_col0" class="data row2 col0" >0.020994</td>
#       <td id="T_d4402_row2_col1" class="data row2 col1" >0.276303</td>
#       <td id="T_d4402_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d4402_row2_col3" class="data row2 col3" >0.108306</td>
#       <td id="T_d4402_row2_col4" class="data row2 col4" >0.164243</td>
#       <td id="T_d4402_row2_col5" class="data row2 col5" >-0.051761</td>
#       <td id="T_d4402_row2_col6" class="data row2 col6" >-0.007913</td>
#       <td id="T_d4402_row2_col7" class="data row2 col7" >0.121690</td>
#       <td id="T_d4402_row2_col8" class="data row2 col8" >0.156654</td>
#       <td id="T_d4402_row2_col9" class="data row2 col9" >0.111038</td>
#       <td id="T_d4402_row2_col10" class="data row2 col10" >0.127904</td>
#     </tr>
#     <tr>
#       <th id="T_d4402_level0_row3" class="row_heading level0 row3" >heart_disease</th>
#       <td id="T_d4402_row3_col0" class

# %% [markdown]
# Splitting the data into training and testing

# %%
X = newdf.drop('stroke',axis=1)
y = newdf['stroke']

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.25, random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((3832, 10), (1278, 10))

# %% [markdown]
# # *KNN*-Model and accuracy

# %% [markdown]
# First we test the error for k values to identify the best k value

# %%
error = []
# Calculating error for K values between 1 and 30
for i in range(1, 30):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error.append(np.mean(pred_i != y_test))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 30), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Error Rate K Value')
plt.xlabel('K Value')
plt.ylabel('Mean Error')
print("Minimum error:-",min(error),"at K =",error.index(min(error))+1)
# Out:
# Minimum error:- 0.05086071987480438 at K = 4

# %% [markdown]
# Building the model

# %%
knn = KNeighborsClassifier(4) # Define classifier
knn.fit(X_train, y_train) # Train model

# Make predictions
y_train_pred_knn = knn.predict(X_train)
y_test_pred_knn = knn.predict(X_test)

# Training set performance
knn_train_accuracy = accuracy_score(y_train, y_train_pred_knn) # Calculate Accuracy
knn_train_f1 = f1_score(y_train, y_train_pred_knn, average='weighted') # Calculate F1-score

# Test set performance
knn_test_accuracy = accuracy_score(y_test, y_test_pred_knn) # Calculate Accuracy
knn_test_f1 = f1_score(y_test, y_test_pred_knn, average='weighted') # Calculate F1-score

print('Model performance for Training set')
print('- Accuracy: %s' % knn_train_accuracy)
print('- F1 score: %s' % knn_train_f1)
print('----------------------------------')
print('Model performance for Test set')
print('- Accuracy: %s' % knn_test_accuracy)
print('- F1 score: %s' % knn_test_f1)
# Out:
# Model performance for Training set
# - Accuracy: 0.9535490605427975
# - F1 score: 0.9328061133637023
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9491392801251957
# - F1 score: 0.92437249842783

# %% [markdown]
# Confusion matrix of knn model

# %%
cm= confusion_matrix(y_test, y_test_pred_knn)
print(confusion_matrix(y_test,y_test_pred_knn))
# Out:
# [[1213    0]
#  [  65    0]]

# %%
print(classification_report(y_test,y_test_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1213
#            1       0.00      0.00      0.00        65
#
#     accuracy                           0.95      1278
#    macro avg       0.47      0.50      0.49      1278
# weighted avg       0.90      0.95      0.92      1278
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# Logistic Regression Model

# %%
log_reg=LogisticRegression()
log_reg.fit(X_train,y_train)
# Make predictions
y_train_pred_LR = log_reg.predict(X_train)
y_test_pred_LR = log_reg.predict(X_test)

# Training set performance
LR_train_accuracy = accuracy_score(y_train, y_train_pred_LR) # Calculate Accuracy
LR_train_f1 = f1_score(y_train, y_train_pred_LR, average='weighted') # Calculate F1-score

# Test set performance
LR_test_accuracy = accuracy_score(y_test, y_test_pred_LR) # Calculate Accuracy
LR_test_f1 = f1_score(y_test, y_test_pred_LR, average='weighted') # Calculate F1-score

print('Model performance for Training set')
print('- Accuracy: %s' % LR_train_accuracy)
print('- F1 score: %s' % LR_train_f1)
print('----------------------------------')
print('Model performance for Test set')
print('- Accuracy: %s' % LR_test_accuracy)
print('- F1 score: %s' % LR_test_f1)
# Out:
# Model performance for Training set
# - Accuracy: 0.9498956158663883
# - F1 score: 0.9298654831336568
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9475743348982786
# - F1 score: 0.923589930278515
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
cm= confusion_matrix(y_test, y_test_pred_LR)
print(confusion_matrix(y_test,y_test_pred_LR))
# Out:
# [[1211    2]
#  [  65    0]]

# %%
print(classification_report(y_test,y_test_pred_LR))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1213
#            1       0.00      0.00      0.00        65
#
#     accuracy                           0.95      1278
#    macro avg       0.47      0.50      0.49      1278
# weighted avg       0.90      0.95      0.92      1278

# %% [markdown]
# Testing if scaling improves the accuracy of our model further for the logistic regression

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
Lr = LogisticRegression()
Lr.fit(X_train, y_train)
predicted=Lr.predict(X_test)
conf = confusion_matrix(y_test, predicted)
print ("Confusion Matrix : \n", conf)
print ("Accuracy of Logistic Regression: ", accuracy_score(y_test, predicted)*100, "%")
# Out:
# Confusion Matrix :
#  [[1213    0]
#  [  65    0]]
# Accuracy of Logistic Regression:  94.91392801251956 %

# %%
KNN = KNeighborsClassifier(4)
KNN.fit(X_train, y_train)
predicted=KNN.predict(X_test)
conf = confusion_matrix(y_test, predicted)
print ("Confusion Matrix : \n", conf)
print ("Accuracy of KNN: ", accuracy_score(y_test, predicted)*100, "%")
# Out:
# Confusion Matrix :
#  [[1213    0]
#  [  64    1]]
# Accuracy of KNN:  94.99217527386541 %

# %% [markdown]
# We can see that both the models improved a little bit on the accuracy after using the standard scaling technique
